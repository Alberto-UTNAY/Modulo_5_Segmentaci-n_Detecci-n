# %% [markdown]
# <a href="https://colab.research.google.com/github/Alberto-UTNAY/Modulo_5_Segmentaci-n_Detecci-n/blob/main/6_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Convolución para MNIST-1D**
#
# Este cuaderno explora una red convolucional 1D para MNIST-1D.
#
# Ejecuta las celdas en orden. En varios lugares verás la palabra "TAREA": sigue esas instrucciones, anticipa qué ocurrirá o escribe el código necesario para completar las funciones.

# %%
# Ejecuta esta celda una vez si necesitas instalar el repositorio MNIST-1D
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-ut12gy97
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-ut12gy97
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.6.17)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=238019dfcc160858ec129fe416c88c7324fe99469f3befb9ff61c784ecd8d1f6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1ga4tj7u/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# Las entradas y salidas de entrenamiento y prueba están en
# data['x'], data['y'], data['x_test'] y data['y_test']
print("Samples in training set: {}".format(len(data['y'])))
print("Samples in test set: {}".format(len(data['y_test'])))
print("Length of each sample: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Samples in training set: 4000
# Samples in test set: 1000
# Length of each sample: 40

# %%
# Carga los datos
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Muestra los tamaños
print("Training data: %d samples (columns), each with %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d samples (columns), each with %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Training data: 4000 samples (columns), each with 40 dimensions (rows)
# Validation data: 1000 samples (columns), each with 40 dimensions (rows)

# %% [markdown]
# Define la red

# %%
# Estos datos tienen 40 dimensiones de entrada y 10 dimensiones de salida
# Las entradas corresponden a los 40 desplazamientos de la plantilla MNIST-1D.
D_i = 40
# Las salidas corresponden a los 10 dígitos
D_o = 10

# TAREA: crea un modelo con las siguientes capas
# 1. Capa convolucional (entrada: longitud 40 y 1 canal; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 2. ReLU
# 3. Capa convolucional (entrada: longitud 19 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 4. ReLU
# 5. Capa convolucional (entrada: longitud 9 y 15 canales; kernel 3; paso 2; padding="valid"; 15 canales de salida)
# 6. ReLU
# 7. Aplanamiento (convierte 4x15) a longitud 60
# 8. Capa lineal (tamaño de entrada = 60, tamaño de salida = 10)
# Documentación útil:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# TEN EN CUENTA QUE LAS CAPAS CONVOLUCIONALES NECESITAN RECIBIR EL NÚMERO DE CANALES DE ENTRADA COMO PARÁMETRO
# Y NO EL TAMAÑO DE LA ENTRADA.

# Reemplaza la siguiente función:
model = nn.Sequential(
nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),

nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),

nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2, padding="valid"),
nn.ReLU(),

nn.Flatten(),
#nn.ReLU(),
nn.Linear(60, 10))

# Esto es una full connected, tienes que cambiarla a Convolutional
# usa nn.Conv y nn.ReLu para las capas convolucionales y nnFlatten
# para aplanar la salida antes de la capa linel final.

# %%
# Inicialización de pesos de He
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# Elige la función de pérdida de entropía cruzada
loss_function = nn.CrossEntropyLoss()
# Construye el optimizador SGD e inicializa la tasa de aprendizaje y el momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# Objeto que reduce la tasa de aprendizaje a la mitad cada 20 épocas
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# Crea los tensores de datos y guárdalos en un DataLoader
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# Carga los datos en una clase que crea los lotes
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Inicializa los pesos del modelo
model.apply(weights_init)

# Recorre el conjunto de datos n_epoch veces
n_epoch = 100
# Guarda la pérdida y el porcentaje de error en cada época
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # Recorre los lotes
  for i, data in enumerate(data_loader):
    # Recupera entradas y etiquetas de este lote
    x_batch, y_batch = data
    # Reinicia los gradientes de los parámetros
    optimizer.zero_grad()
    # Paso hacia adelante: calcula la salida del modelo
    pred = model(x_batch[:,None,:])
    # Calcula la pérdida
    loss = loss_function(pred, y_batch)
    # Paso hacia atrás
    loss.backward()
    # Actualización SGD
    optimizer.step()

  # Ejecuta todo el conjunto de datos para obtener estadísticas; normalmente no harías esto
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, training loss {losses_train[epoch]:.6f}, training error {errors_train[epoch]:3.2f}, validation loss {losses_val[epoch]:.6f}, validation error {errors_val[epoch]:3.2f}')

  # Indica al programador que evalúe si debe actualizar la tasa de aprendizaje
  scheduler.step()

# Grafica los resultados
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='entrenamiento')
ax.plot(errors_val,'b-',label='validación')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# Epoch     0, training loss 1.970650, training error 79.38, validation loss 1.956155, validation error 78.90
# Epoch     1, training loss 1.573460, training error 62.97, validation loss 1.590206, validation error 65.00
# Epoch     2, training loss 1.447758, training error 56.75, validation loss 1.463124, validation error 61.00
# Epoch     3, training loss 1.243050, training error 51.38, validation loss 1.247576, validation error 51.70
# Epoch     4, training loss 1.194541, training error 49.55, validation loss 1.207445, validation error 50.80
# Epoch     5, training loss 1.086313, training error 42.10, validation loss 1.120660, validation error 46.40
# Epoch     6, training loss 1.008848, training error 39.50, validation loss 1.039094, validation error 44.10
# Epoch     7, training loss 0.952901, training error 37.85, validation loss 1.002439, validation error 41.90
# Epoch     8, training loss 0.821002, training error 31.78, validation loss 0.877797, validation error 37.00
# Epoch     9, training loss 0.775301, training error 31.65, validation loss 0.831867, validation error 35.20
# Epoch    10, training loss 0.734071, training error 27.60, validation loss 0.813638, validation error 30.80
# Epoch    11, training loss 0.605502, training error 23.60, validation loss 0.691765, validation error 28.70
# Epoch    12, training loss 0.502113, training error 18.95, validation loss 0.595993, validation error 24.30
# Epoch    13, training loss 0.520929, training error 20.00, validation loss 0.609669, validation error 22.70
# Epoch    14, training loss 0.553281, training error 20.72, validation loss 0.648810, validation error 24.90
# Epoch    15, training loss 0.485668, training error 18.00, validation loss 0.594634, validation error 22.50
# Epoch    16, training loss 0.351494, training error 13.32, validation loss 0.470896, validation error 18.10
# Epoch    17, training loss 0.357414, training error 13.55, validation loss 0.497545, validation error 18.90
# Epoch    18, training loss 0.304305, training error 11.38, validation loss 0.465856, validation error 15.60
# Epoch    19, training loss 0.291101, training error 10.50, validation loss 0.420759, validation error 16.20
# Epoch    20, training loss 0.219450, training error 7.05, validation loss 0.377635, validation error 14.40
# Epoch    21, training loss 0.225970, training error 8.40, validation loss 0.394798, validation error 14.30
# Epoch    22, training loss 0.196164, training error 6.88, validation loss 0.397433, validation error 15.10
# Epoch    23, training loss 0.189578, training error 6.40, validation loss 0.387085, validation error 14.10
# Epoch    24, training loss 0.178136, training error 6.12, validation loss 0.373716, validation error 13.30
# Epoch    25, training loss 0.176233, training error 5.68, validation loss 0.369852, validation error 13.30
# Epoch    26, training loss 0.160703, training error 5.22, validation loss 0.362146, validation error 13.00
# Epoch    27, training loss 0.153594, training error 5.30, validation loss 0.376928, validation error 12.30
# Epoch    28, training loss 0.148846, training error 5.05, validation loss 0.360274, validation error 12.60
# Epoch    29, training loss 0.130208, training error 4.43, validation loss 0.363201, validation error 11.90
# Epoch    30, training loss 0.124632, training error 3.55, validation loss 0.356763, validation error 12.00
# Epoch    31, training loss 0.133139, training error 4.43, validation loss 0.375007, validation error 11.90
# Epoch    32, training loss 0.126031, training error 4.50, validation loss 0.390049, validation error 11.80
# Epoch    33, training loss 0.113308, training error 3.85, validation loss 0.361231, validation error 11.40
# Epoch    34, training loss 0.121787, training error 4.30, validation loss 0.368592, validation error 10.80
# Epoch    35, training loss 0.112371, training error 3.95, validation loss 0.404919, validation error 11.40
# Epoch    36, training loss 0.108735, training error 3.53, validation loss 0.381413, validation error 11.00
# Epoch    37, training loss 0.101066, training error 3.62, validation loss 0.399962, validation error 12.90
# Epoch    38, training loss 0.089276, training error 2.47, validation loss 0.378185, validation error 11.70
# Epoch    39, training loss 0.076727, training error 2.03, validation loss 0.378121, validation error 11.20
# Epoch    40, training loss 0.068771, training error 1.85, validation loss 0.371796, validation error 10.90
# Epoch    41, training loss 0.063966, training error 1.75, validation loss 0.378195, validation error 11.30
# Epoch    42, training loss 0.062055, training error 1.35, validation loss 0.378733, validation error 10.80
# Epoch    43, training loss 0.059994, training error 1.40, validation loss 0.384239, validation error 11.10
# Epoch    44, training loss 0.058416, training error 1.47, validation loss 0.394011, validation error 10.90
# Epoch    45, training loss 0.056075, training error 1.25, validation loss 0.403701, validation error 11.30
# Epoch    46, training loss 0.056138, training error 1.30, validation loss 0.388593, validation error 11.10
# Epoch    47, training loss 0.054970, training error 1.20, validation loss 0.404715, validation error 11.30
# Epoch    48, training loss 0.053307, training error 1.18, validation loss 0.403069, validation error 11.60
# Epoch    49, training loss 0.049574, training error 1.03, validation loss 0.405842, validation error 11.10
# Epoch    50, training loss 0.047032, training error 0.97, validation loss 0.409749, validation error 11.10
# Epoch    51, training loss 0.046556, training error 0.85, validation loss 0.410709, validation error 11.80
# Epoch    52, training loss 0.046440, training error 0.90, validation loss 0.415665, validation error 11.60
# Epoch    53, training loss 0.047375, training error 1.15, validation loss 0.427651, validation error 11.30
# Epoch    54, training loss 0.048665, training error 1.10, validation loss 0.438436, validation error 10.90
# Epoch    55, training loss 0.043611, training error 0.93, validation loss 0.433041, validation error 11.60
# Epoch    56, training loss 0.043079, training error 0.78, validation loss 0.426634, validation error 10.90
# Epoch    57, training loss 0.041620, training error 0.70, validation loss 0.429621, validation error 10.80
# Epoch    58, training loss 0.049113, training error 1.25, validation loss 0.454728, validation error 12.00
# Epoch    59, training loss 0.037512, training error 0.62, validation loss 0.435811, validation error 11.20
# Epoch    60, training loss 0.035502, training error 0.53, validation loss 0.433650, validation error 11.00
# Epoch    61, training loss 0.034770, training error 0.57, validation loss 0.441919, validation error 10.90
# Epoch    62, training loss 0.036731, training error 0.57, validation loss 0.449934, validation error 11.50
# Epoch    63, training loss 0.035452, training error 0.53, validation loss 0.453560, validation error 11.00
# Epoch    64, training loss 0.033304, training error 0.50, validation loss 0.446318, validation error 11.00
# Epoch    65, training loss 0.033658, training error 0.50, validation loss 0.453137, validation error 10.90
# Epoch    66, training loss 0.031944, training error 0.47, validation loss 0.451123, validation error 10.90
# Epoch    67, training loss 0.032188, training error 0.57, validation loss 0.458181, validation error 11.50
# Epoch    68, training loss 0.031725, training error 0.45, validation loss 0.455327, validation error 11.00
# Epoch    69, training loss 0.030950, training error 0.43, validation loss 0.456577, validation error 11.30
# Epoch    70, training loss 0.032680, training error 0.50, validation loss 0.466649, validation error 10.70
# Epoch    71, training loss 0.032027, training error 0.47, validation loss 0.459791, validation error 10.80
# Epoch    72, training loss 0.030427, training error 0.43, validation loss 0.464319, validation error 11.10
# Epoch    73, training loss 0.029127, training error 0.38, validation loss 0.464699, validation error 11.20
# Epoch    74, training loss 0.028964, training error 0.35, validation loss 0.470614, validation error 10.70
# Epoch    75, training loss 0.031976, training error 0.57, validation loss 0.474762, validation error 11.70
# Epoch    76, training loss 0.028930, training error 0.32, validation loss 0.475274, validation error 10.70
# Epoch    77, training loss 0.028726, training error 0.38, validation loss 0.475730, validation error 11.40
# Epoch    78, training loss 0.029015, training error 0.35, validation loss 0.480666, validation error 10.80
# Epoch    79, training loss 0.027114, training error 0.43, validation loss 0.474767, validation error 11.00
# Epoch    80, training loss 0.027773, training error 0.22, validation loss 0.482823, validation error 10.60
# Epoch    81, training loss 0.026358, training error 0.32, validation loss 0.480109, validation error 11.50
# Epoch    82, training loss 0.026676, training error 0.25, validation loss 0.484595, validation error 11.00
# Epoch    83, training loss 0.025958, training error 0.30, validation loss 0.482438, validation error 11.00
# Epoch    84, training loss 0.025699, training error 0.30, validation loss 0.483352, validation error 11.10
# Epoch    85, training loss 0.025737, training error 0.22, validation loss 0.485441, validation error 11.20
# Epoch    86, training loss 0.026175, training error 0.35, validation loss 0.486825, validation error 11.40
# Epoch    87, training loss 0.025393, training error 0.28, validation loss 0.486922, validation error 10.90
# Epoch    88, training loss 0.025411, training error 0.30, validation loss 0.487388, validation error 11.20
# Epoch    89, training loss 0.025027, training error 0.32, validation loss 0.489269, validation error 11.10
# Epoch    90, training loss 0.024915, training error 0.25, validation loss 0.490855, validation error 11.30
# Epoch    91, training loss 0.024573, training error 0.22, validation loss 0.493463, validation error 10.90
# Epoch    92, training loss 0.024712, training error 0.20, validation loss 0.492755, validation error 10.70
# Epoch    93, training loss 0.024341, training error 0.25, validation loss 0.494546, validation error 11.10
# Epoch    94, training loss 0.024218, training error 0.20, validation loss 0.494159, validation error 11.10
# Epoch    95, training loss 0.024068, training error 0.20, validation loss 0.496323, validation error 11.20
# Epoch    96, training loss 0.023823, training error 0.25, validation loss 0.496861, validation error 11.20
# Epoch    97, training loss 0.023805, training error 0.28, validation loss 0.496914, validation error 11.50
# Epoch    98, training loss 0.023788, training error 0.28, validation loss 0.500444, validation error 11.20
# Epoch    99, training loss 0.023364, training error 0.20, validation loss 0.499318, validation error 11.30
